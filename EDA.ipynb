# %% [markdown]
# <a href="https://colab.research.google.com/github/jjuandiego099/cuadernos-y-proyectos-IA/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cuaderno de practica de tipo de datos

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# crear un dataframe

# %%
https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasificacion.csv

# %%
df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasificacion.csv')
df
# Out:
#      habitaciones  Area_parqeo  Are total  Valor_Miles  Clasifi
# 0             4.0         4.98        153     504000.0        2
# 1             4.0         9.14        178     453600.0        2
# 2             5.0         4.03        178     728700.0        3
# 3             4.0         2.94        187     701400.0        3
# 4             5.0         5.33        187     760200.0        2
# ..            ...          ...        ...          ...      ...
# 494           4.0         9.67        210          NaN        2
# 495           4.0         9.08        210          NaN        2
# 496           4.0         5.64        210          NaN        2
# 497           4.0         6.48        210          NaN        2
# 498           4.0         7.88        210          NaN        1
#
# [499 rows x 5 columns]

# %%
df.describe()
# Out:
#        habitaciones  Area_parqeo   Are total   Valor_Miles    Clasifi
# count    497.000000   496.000000  499.000000  4.940000e+02  499.00000
# mean       3.738431    12.906190  185.482966  4.537190e+05    2.02004
# std        0.726786     7.062445   21.055988  1.646495e+05    0.78105
# min        1.000000     1.980000  126.000000  1.050000e+05    1.00000
# 25%        3.000000     7.362500  174.000000  3.512250e+05    2.00000
# 50%        4.000000    11.655000  191.000000  4.368000e+05    2.00000
# 75%        4.000000    17.112500  202.000000  5.166000e+05    2.00000
# max        6.000000    37.970000  220.000000  1.024800e+06    4.00000

# %%
# prompt: grafica de barras de habitaciones

import pandas as pd
import matplotlib.pyplot as plt

# Load the dataframe (assuming the previous code was executed)
df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasificacion.csv')

# Create the bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
df['habitaciones'].value_counts().plot(kind='bar')
plt.title('Distribución de Habitaciones de la vivienda')
plt.xlabel('Número de Habitaciones')
plt.ylabel('Cantidad de Viviendas')
plt.xticks(rotation=0)  # Rotate x-axis labels if needed
plt.show()

# %%
df['habitaciones'].value_counts()
# Out:
# habitaciones
# 4.0    274
# 3.0    158
# 5.0     44
# 2.0     12
# 6.0      7
# 1.0      2
# Name: count, dtype: int64

# %%
df.size,df.shape
# Out:
# (2495, (499, 5))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   habitaciones  497 non-null    float64
#  1   Area_parqeo   496 non-null    float64
#  2   Are total     499 non-null    int64
#  3   Valor_Miles   494 non-null    float64
#  4   Clasifi       499 non-null    int64
# dtypes: float64(3), int64(2)
# memory usage: 19.6 KB

# %%
# prompt: promedio habitaciones

# Calculate the average number of rooms
average_rooms = df['habitaciones'].mean()

print(f"El promedio de habitaciones es: {average_rooms}")
# Out:
# El promedio de habitaciones es: 3.738430583501006

# %%
average_rooms = df['habitaciones'].median()

print(f"La mediana de habitaciones es: {average_rooms}")
# Out:
# El promedio de habitaciones es: 4.0

# %%
df.describe()
# Out:
#        habitaciones  Area_parqeo   Are total   Valor_Miles    Clasifi
# count    497.000000   496.000000  499.000000  4.940000e+02  499.00000
# mean       3.738431    12.906190  185.482966  4.537190e+05    2.02004
# std        0.726786     7.062445   21.055988  1.646495e+05    0.78105
# min        1.000000     1.980000  126.000000  1.050000e+05    1.00000
# 25%        3.000000     7.362500  174.000000  3.512250e+05    2.00000
# 50%        4.000000    11.655000  191.000000  4.368000e+05    2.00000
# 75%        4.000000    17.112500  202.000000  5.166000e+05    2.00000
# max        6.000000    37.970000  220.000000  1.024800e+06    4.00000

# %%
# prompt: crea  caja de bigotes Area_parqeo

import matplotlib.pyplot as plt

# Assuming 'df' is already loaded as in the previous code
# Create the box plot
plt.figure(figsize=(8, 6))
df.boxplot(column=['Area_parqeo'])  # vert=False for horizontal boxplot
plt.title('Box Plot of Parking Area')
plt.xlabel('Area_parqeo')
plt.show()

# %%
# prompt: borrar todos los registros que sean superior a 32 y dejarlo en el mismo df

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataframe
df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasificacion.csv')

# Delete rows where 'habitaciones' is greater than 32
df = df[df['Area_parqeo'] <= 31]
plt.figure(figsize=(8, 6))
df.boxplot(column=['Area_parqeo'])  # vert=False for horizontal boxplot
plt.title('Box Plot of Parking Area')
plt.xlabel('Area_parqeo')
plt.show()

# %%
df.shape
# Out:
# (489, 5)

# %%
df.isnull().sum()
# Out:
# habitaciones    2
# Area_parqeo     0
# Are total       0
# Valor_Miles     5
# Clasifi         0
# dtype: int64

# %% [markdown]
# arreglos son de un solo tpo de variable(numpy) y dataframe son diferente tipos de datos(pandas)

# %%
# prompt: crear un arreglo con la vaiable datos, con datos sinteticos usando numpy dodne la columna 0 sea la edad y la columna 1 sean las notas de IA que van de 0 a 5, las edaddes no pueden ser decimanles y la nota redondeala a 2 decimales

import numpy as np

# Set a seed for reproducibility
np.random.seed(42)

# Number of samples
n_samples = 20

# Generate ages (integers between 18 and 65)
edades = np.random.randint(18, 25, size=n_samples)

# Generate IA grades (floats between 0 and 5, rounded to 2 decimal places)
notas_ia = np.round(np.random.uniform(0, 5,  size=n_samples), 2)

# Create the array
datos = np.column_stack((edades, notas_ia))

datos
# Out:
# array([[24.  ,  4.69],
#        [21.  ,  0.  ],
#        [22.  ,  4.96],
#        [24.  ,  3.09],
#        [20.  ,  3.06],
#        [22.  ,  0.04],
#        [22.  ,  0.12],
#        [24.  ,  2.62],
#        [19.  ,  2.  ],
#        [20.  ,  0.23],
#        [24.  ,  4.87],
#        [20.  ,  1.16],
#        [20.  ,  0.45],
#        [22.  ,  3.09],
#        [21.  ,  1.91],
#        [20.  ,  4.92],
#        [23.  ,  2.33],
#        [22.  ,  4.3 ],
#        [19.  ,  3.4 ],
#        [21.  ,  2.25]])

# %%
# prompt: calcula el promedia de la columna 1 del arreglo de datos

# Assuming 'datos' is the NumPy array from the previous code
# Calculate the average of the first column (edades)

average_age = np.mean(datos[:, 1])

print(f"El promedio de la columna 1 (notas) es: {average_age}")
# Out:
# El promedio de la columna 1 (notas) es: 2.4745

# %%
datos[:99,:]
# Out:
# array([[24.  ,  4.69],
#        [21.  ,  0.  ],
#        [22.  ,  4.96],
#        [24.  ,  3.09],
#        [20.  ,  3.06],
#        [22.  ,  0.04],
#        [22.  ,  0.12],
#        [24.  ,  2.62],
#        [19.  ,  2.  ],
#        [20.  ,  0.23],
#        [24.  ,  4.87],
#        [20.  ,  1.16],
#        [20.  ,  0.45],
#        [22.  ,  3.09],
#        [21.  ,  1.91],
#        [20.  ,  4.92],
#        [23.  ,  2.33],
#        [22.  ,  4.3 ],
#        [19.  ,  3.4 ],
#        [21.  ,  2.25]])

# %% [markdown]
# datos sintenticos

# %%
identidad=np.eye(9,9)
identidad.shape
# Out:
# (9, 9)

# %%
# prompt: crear una lista de nombre de alumnos sinetiticos en una variable llamanda nombres

nombres = ["Efrain", "Jackson", "Olivia", "Aiden", "Emma", "Lucas", "Ava", "Liam", "Mia", "Noah", "Isabella", "Ethan", "Riley", "Mason", "Aria", "Caden", "Zoe", "Oliver", "Charlotte", "Elijah"]

nombres
# Out:
# ['Efrain',
#  'Jackson',
#  'Olivia',
#  'Aiden',
#  'Emma',
#  'Lucas',
#  'Ava',
#  'Liam',
#  'Mia',
#  'Noah',
#  'Isabella',
#  'Ethan',
#  'Riley',
#  'Mason',
#  'Aria',
#  'Caden',
#  'Zoe',
#  'Oliver',
#  'Charlotte',
#  'Elijah']

# %% [markdown]
# tipos de satos object

# %%
# prompt: crear un dataframe llamado alumnos donde integramos el arreglo nombres,edades,notas_ia

import pandas as pd

# Assuming nombres, edades, and notas_ia are already defined as in your previous code
# Create a dictionary to store the data
data = {'nombres': nombres, 'edades': edades, 'notas_ia': notas_ia}

# Create the DataFrame
alumnos = pd.DataFrame(data)

# Display the DataFrame
alumnos
# Out:
#       nombres  edades  notas_ia
# 0      Efrain      24      4.69
# 1     Jackson      21      0.00
# 2      Olivia      22      4.96
# 3       Aiden      24      3.09
# 4        Emma      20      3.06
# 5       Lucas      22      0.04
# 6         Ava      22      0.12
# 7        Liam      24      2.62
# 8         Mia      19      2.00
# 9        Noah      20      0.23
# 10   Isabella      24      4.87
# 11      Ethan      20      1.16
# 12      Riley      20      0.45
# 13      Mason      22      3.09
# 14       Aria      21      1.91
# 15      Caden      20      4.92
# 16        Zoe      23      2.33
# 17     Oliver      22      4.30
# 18  Charlotte      19      3.40
# 19     Elijah      21      2.25

# %%
alumnos.shape
# Out:
# (20, 3)

# %%
alumnos.dtypes
# Out:
# nombres      object
# edades        int64
# notas_ia    float64
# dtype: object

# %%
alumnos['edades'].mean()
# Out:
# 21.5

# %%
alumnos['notas_ia'].max()
# Out:
# 4.96

# %%
alumnos["nombres"][alumnos.notas_ia>=4]
# Out:
# 0       Efrain
# 2       Olivia
# 10    Isabella
# 15       Caden
# 17      Oliver
# Name: nombres, dtype: object

# %%
alumnos.nombres[alumnos.notas_ia>=4]
# Out:
# 0       Efrain
# 2       Olivia
# 10    Isabella
# 15       Caden
# 17      Oliver
# Name: nombres, dtype: object

# %% [markdown]
# python chart

# %%
alumnos.edades.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
alumnos.notas_ia.plot(kind='pie',title='notas_ia',figsize=(6,6),autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'notas_ia'}, ylabel='notas_ia'>

# %%
# prompt: con matplolib haga la boxplot de las notas_ia con titulo y axis

import matplotlib.pyplot as plt

# Assuming 'alumnos' DataFrame is already created as in the previous code

plt.figure(figsize=(8, 6))
plt.boxplot(alumnos['notas_ia'], vert=True)  # vert=False for horizontal boxplot
plt.title('Box Plot of IA Grades')
plt.xlabel('IA Grades')
plt.show()

# %% [markdown]
# cardinalidad en dataset: diferentes valores que pueden tomar un feature

# %% [markdown]
# La curtosis es una medida estadística que describe la forma de la distribución de una variable, especialmente en relación con la "altitud" y "ancho" de las colas de la distribución.

# %% [markdown]
# para que la data este balanceada no puede haber una diferencia mayor al 30% entre features

# %% [markdown]
# cuando la correlacion aumenta el 80% una de las variables se elimina, se elimina la que menor varianza tenga

# %% [markdown]
# si una columna tiene mas de 30% nulos se piensa en borrar la columna

# %%
df
# Out:
#      habitaciones  Area_parqeo  Are total  Valor_Miles  Clasifi  Nota_Ciencias
# 0             4.0         4.98        153     504000.0        2            NaN
# 1             4.0         9.14        178     453600.0        2            NaN
# 2             5.0         4.03        178     728700.0        3            NaN
# 3             4.0         2.94        187     701400.0        3            NaN
# 4             5.0         5.33        187     760200.0        2            NaN
# ..            ...          ...        ...          ...      ...            ...
# 494           4.0         9.67        210          NaN        2            NaN
# 495           4.0         9.08        210          NaN        2            NaN
# 496           4.0         5.64        210          NaN        2            NaN
# 497           4.0         6.48        210          NaN        2            NaN
# 498           4.0         7.88        210          NaN        1            NaN
#
# [489 rows x 6 columns]

# %%
df[df["Nota_Ciencias"].isnull()]
# Out:
#      habitaciones  Area_parqeo  Are total  Valor_Miles  Clasifi  Nota_Ciencias
# 0             4.0         4.98        153     504000.0        2            NaN
# 1             4.0         9.14        178     453600.0        2            NaN
# 2             5.0         4.03        178     728700.0        3            NaN
# 3             4.0         2.94        187     701400.0        3            NaN
# 4             5.0         5.33        187     760200.0        2            NaN
# ..            ...          ...        ...          ...      ...            ...
# 494           4.0         9.67        210          NaN        2            NaN
# 495           4.0         9.08        210          NaN        2            NaN
# 496           4.0         5.64        210          NaN        2            NaN
# 497           4.0         6.48        210          NaN        2            NaN
# 498           4.0         7.88        210          NaN        1            NaN
#
# [489 rows x 6 columns]

# %% [markdown]
# cuando la correlacion es negativa y menor a 0.80 se elimina la de menor varianza

# %% [markdown]
# en cardinalidad de one hot code son las variables -1

# %% [markdown]
# get dumies es un metodo de pandas

# %% [markdown]
# onehotencoder es una libreria de sikit learn  que su función principal es convertir variables categóricas en variables numéricas de manera que los algoritmos puedan procesarlas de forma más eficiente.
